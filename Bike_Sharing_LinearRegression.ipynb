# %% [markdown]
# # Problem Statement
# ### This assignment is a programming assignment wherein to build a multiple linear regression model for the prediction of demand for shared bikes
#
# # Business Goal
# ### Required to model the demand for shared bikes with the available independent variables. It will be used by the management to understand how exactly the demands vary with different features. They can accordingly manipulate the business strategy to meet the demand levels and meet the customer's expectations. Further, the model will be a good way for management to understand the demand dynamics of a new market.

# %% [markdown]
# ## Importing Libraries

# %%
# Import the numpy and pandas package
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 500)

# Importing the required libraries for plots.
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#Machine learning Libraries
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# # Step 1: Reading and Understanding the Data

# %%
## reading data
bike_data = pd.read_csv('day.csv')

# %%
# Check the head of the dataset
bike_data.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
# 3        4  04-01-2018       1   0     1        0        2           1
# 4        5  05-01-2018       1   0     1        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# ### Understanding the bike dataframe

# %%
bike_data.shape
# Out:
# (730, 16)

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
bike_data.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.997260
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.006161
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.683562    1.394521   20.319259   23.726322   62.765175   12.763620
# ...

# %% [markdown]
# #### Since the difference between mean and median is not much , we can conclude that data has no outliers

# %% [markdown]
# # Step 2: Data Visualisation

# %% [markdown]
# ### Visualising Numeric Variables
#
# Let's make a pairplot of all the numeric variables

# %%
sns.pairplot(data=bike_data,vars=['cnt', 'temp', 'atemp', 'hum','windspeed'])
plt.show()

# %% [markdown]
#  <div class="alert alert-block alert-info">
#     <span style='font-family:Georgia'>
#         <b>Insight:</b>
#         <ul>
#         <li>Fetaure Temp and aTemp is highly corelated </li>
#         <ul>
#     </span>
# </div>

# %% [markdown]
# ### Visualising Categorical Variables

# %%
plt.figure(figsize=(20, 12))
plt.subplot(2,3,1)
sns.boxplot(x = 'season', y = 'cnt', data = bike_data)
plt.subplot(2,3,2)
sns.boxplot(x = 'mnth', y = 'cnt', data = bike_data)
plt.subplot(2,3,3)
sns.boxplot(x = 'holiday', y = 'cnt', data = bike_data)
plt.subplot(2,3,4)
sns.boxplot(x = 'weathersit', y = 'cnt', data = bike_data)
plt.subplot(2,3,5)
sns.boxplot(x = 'yr', y = 'cnt', data = bike_data)
plt.subplot(2,3,6)
sns.boxplot(x = 'weekday', y = 'cnt', data = bike_data)
plt.show()

# %%
plt.figure(figsize = (10, 5))
sns.boxplot(x = 'workingday', y = 'cnt', data = bike_data)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <span style='font-family:Georgia'>
#         <b>Insight:</b>
#         <ul>
#         <li>a) Bike rental count in year 2019 > 2018 </li>
#         <li>b) Bike rental count in Season Fall > summer > winter > spring</li>
#         <li>c) Bike rental count in Working Days > Holidays </li>
#         <li>d) Bike rental count in weather clear > mist+cloudy > Light Snow </li>
#         <li>e) Bike rental count in September and October month is High </li>
#         <ul>
#     </span>
# </div>

# %%
#Heatmap to see correlation between variables
plt.figure(figsize=(25, 12))
sns.heatmap(bike_data.corr(), cmap='RdYlGn', annot = True)
plt.title("Correlation between Variables")
plt.show()

# %% [markdown]
# # Step 3: Data Preparation

# %%
## dropping columns that are irrelevant for the model - 
bike_data.drop(['instant','dteday','casual','registered'],axis = 1,inplace = True)
bike_data.head()
# Out:
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1   0     1        0        6           0           2  14.110847
# 1       1   0     1        0        0           0           2  14.902598
# 2       1   0     1        0        1           1           1   8.050924
# 3       1   0     1        0        2           1           1   8.200000
# 4       1   0     1        0        3           1           1   9.305237
#
#       atemp      hum  windspeed   cnt
# 0  18.18125  80.5833  10.749882   985
# 1  17.68695  69.6087  16.652113   801
# 2   9.47025  43.7273  16.636703  1349
# 3  10.60610  59.0435  10.739832  1562
# 4  11.46350  43.6957  12.522300  1600

# %%
### Converting some numeric values to categorical data
import calendar
bike_data['mnth'] = bike_data['mnth'].apply(lambda x: calendar.month_abbr[x])
bike_data.season = bike_data.season.map({1: 'Spring',2:'Summer',3:'Fall',4:'Winter'})
bike_data.weathersit = bike_data.weathersit.map({1:'Clear',2:'Mist & Cloudy', 
                                             3:'Light Snow & Rain',4:'Heavy Snow & Rain'})
bike_data.weekday = bike_data.weekday.map({0:"Sunday",1:"Monday",2:"Tuesday",3:"Wednesday",4:"Thrusday",5:"Friday",6:"Saturday"})

# %%
bike_data.head()
# Out:
#    season  yr mnth  holiday    weekday  workingday     weathersit       temp  \
# 0  Spring   0  Jan        0   Saturday           0  Mist & Cloudy  14.110847
# 1  Spring   0  Jan        0     Sunday           0  Mist & Cloudy  14.902598
# 2  Spring   0  Jan        0     Monday           1          Clear   8.050924
# 3  Spring   0  Jan        0    Tuesday           1          Clear   8.200000
# 4  Spring   0  Jan        0  Wednesday           1          Clear   9.305237
#
#       atemp      hum  windspeed   cnt
# 0  18.18125  80.5833  10.749882   985
# 1  17.68695  69.6087  16.652113   801
# 2   9.47025  43.7273  16.636703  1349
# 3  10.60610  59.0435  10.739832  1562
# 4  11.46350  43.6957  12.522300  1600

# %% [markdown]
# ### Dummy Variables

# %%
### creating dummy variables for season , mnth ,weathersit ,weekday
dummy = bike_data[['season','mnth','weekday','weathersit']]
dummy = pd.get_dummies(dummy,drop_first=True )
bike_data = pd.concat([dummy,bike_data],axis = 1)

# %%
## dropping columns for which dummy variables were created
bike_data.drop(['season', 'mnth', 'weekday','weathersit'], axis = 1, inplace = True)

# %% [markdown]
# # Step 4: Splitting the Data into Training and Testing Sets

# %%
train, test = train_test_split(bike_data, train_size = 0.7, test_size = 0.3, random_state = 100)

# %% [markdown]
# ## Rescaling the Features Using MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
# Apply scaler() to all the columns except the 'dummy' variables.
num_vars = ['cnt','hum','windspeed','temp','atemp']

train[num_vars] = scaler.fit_transform(train[num_vars])

# %%
train.head()
# Out:
#      season_Spring  season_Summer  season_Winter  mnth_Aug  mnth_Dec  \
# 653              0              0              1         0         0
# 576              0              0              0         0         0
# 426              1              0              0         0         0
# 728              1              0              0         0         1
# 482              0              1              0         0         0
#
#      mnth_Feb  mnth_Jan  mnth_Jul  mnth_Jun  mnth_Mar  mnth_May  mnth_Nov  \
# 653         0         0         0         0         0         0         0
# 576         0         0         1         0         0         0         0
# 426         0         0         0         0         1         0         0
# 728         0         0         0         0         0         0         0
# 482         0         0         0         0         0         0         0
#
#      mnth_Oct  mnth_Sep  weekday_Monday  weekday_Saturday  weekday_Sunday  \
# ...

# %%
train.describe()
# Out:
#        season_Spring  season_Summer  season_Winter    mnth_Aug    mnth_Dec  \
# count     510.000000     510.000000      510.00000  510.000000  510.000000
# mean        0.243137       0.245098        0.24902    0.096078    0.084314
# std         0.429398       0.430568        0.43287    0.294988    0.278131
# min         0.000000       0.000000        0.00000    0.000000    0.000000
# 25%         0.000000       0.000000        0.00000    0.000000    0.000000
# 50%         0.000000       0.000000        0.00000    0.000000    0.000000
# 75%         0.000000       0.000000        0.00000    0.000000    0.000000
# max         1.000000       1.000000        1.00000    1.000000    1.000000
#
#          mnth_Feb    mnth_Jan    mnth_Jul    mnth_Jun    mnth_Mar    mnth_May  \
# count  510.000000  510.000000  510.000000  510.000000  510.000000  510.000000
# mean     0.066667    0.088235    0.076471    0.074510    0.098039    0.084314
# ...

# %%
# Let's check the correlation coefficients to see which variables are highly correlated

plt.figure(figsize = (20, 10))
sns.heatmap(train.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# ### Dividing into X and Y sets for the model building

# %%
y_train = train.pop('cnt')
X_train = train

# %% [markdown]
# # Step 5: Building a linear model

# %% [markdown]
# ### Function For calculating VIF

# %%
def calculateVIF(df):
    vif = pd.DataFrame()
    vif['Features'] = df.columns
    vif['VIF'] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
    vif['VIF'] = round(vif['VIF'], 2)
    vif = vif.sort_values(by = "VIF", ascending = False)
    return vif

# %%
# Running RFE with the output number of the variable equal to 13
lm = LinearRegression()
lm.fit(X_train, y_train)

rfe = RFE(lm, 13)             
rfe = rfe.fit(X_train, y_train)

# %%
#Columns selected by RFE and their weights
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('season_Spring', True, 1),
#  ('season_Summer', True, 1),
#  ('season_Winter', True, 1),
#  ('mnth_Aug', False, 9),
#  ('mnth_Dec', False, 5),
#  ('mnth_Feb', False, 6),
#  ('mnth_Jan', False, 3),
#  ('mnth_Jul', True, 1),
#  ('mnth_Jun', False, 16),
#  ('mnth_Mar', False, 17),
#  ('mnth_May', False, 8),
#  ('mnth_Nov', False, 4),
#  ('mnth_Oct', False, 13),
#  ('mnth_Sep', True, 1),
#  ('weekday_Monday', False, 11),
#  ('weekday_Saturday', True, 1),
#  ('weekday_Sunday', False, 10),
#  ('weekday_Thrusday', False, 14),
#  ('weekday_Tuesday', False, 12),
#  ('weekday_Wednesday', False, 15),
#  ('weathersit_Light Snow & Rain', True, 1),
#  ('weathersit_Mist & Cloudy', True, 1),
#  ('yr', True, 1),
#  ('holiday', True, 1),
#  ('workingday', False, 2),
#  ('temp', True, 1),
#  ('atemp', False, 7),
#  ('hum', True, 1),
#  ('windspeed', True, 1)]

# %% [markdown]
# ### RFE Accepted/Rejected Columns

# %%
#Print Columns selected by RFE. We will start with these columns for manual elimination
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['season_Spring', 'season_Summer', 'season_Winter', 'mnth_Jul',
#        'mnth_Sep', 'weekday_Saturday', 'weathersit_Light Snow & Rain',
#        'weathersit_Mist & Cloudy', 'yr', 'holiday', 'temp', 'hum',
#        'windspeed'],
#       dtype='object')

# %%
X_train.columns[~rfe.support_]
# Out:
# Index(['mnth_Aug', 'mnth_Dec', 'mnth_Feb', 'mnth_Jan', 'mnth_Jun', 'mnth_Mar',
#        'mnth_May', 'mnth_Nov', 'mnth_Oct', 'weekday_Monday', 'weekday_Sunday',
#        'weekday_Thrusday', 'weekday_Tuesday', 'weekday_Wednesday',
#        'workingday', 'atemp'],
#       dtype='object')

# %% [markdown]
# ## Using StatsModel For Building Model

# %%
# Creating X_test dataframe with RFE selected variables
X_train_rfe = X_train[col]

# %%
# Adding a constant variable 
 
X_train_rfe = sm.add_constant(X_train_rfe)

# %%
# Create a first fitted model
lm = sm.OLS(y_train,X_train_rfe).fit()

# %%
# Check the parameters obtained

lm.params
# Out:
# const                           0.279640
# season_Spring                  -0.056290
# season_Summer                   0.052092
# season_Winter                   0.098387
# mnth_Jul                       -0.057853
# mnth_Sep                        0.082751
# weekday_Saturday                0.017490
# weathersit_Light Snow & Rain   -0.239456
# weathersit_Mist & Cloudy       -0.054750
# yr                              0.229791
# holiday                        -0.094469
# temp                            0.530609
# hum                            -0.168105
# windspeed                      -0.183143
# dtype: float64

# %%
# Print a summary of the linear regression model obtained
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.839
# Method:                 Least Squares   F-statistic:                     205.0
# Date:                Tue, 15 Mar 2022   Prob (F-statistic):          7.51e-190
# Time:                        20:49:09   Log-Likelihood:                 510.75
# No. Observations:                 510   AIC:                            -993.5
# Df Residuals:                     496   BIC:                            -934.2
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                            0.2796      0.035      8.096      0.000       0.212       0.348
# ...

# %% [markdown]
# ### StatsModel - Linear Model #2 (dropping weekday_Saturday since it has p > 0.05)

# %%
X_train_new = X_train_rfe.drop(["weekday_Saturday"], axis = 1)

# %% [markdown]
# Rebuilding the model without 'weekday_Saturday'

# %%
# Adding a constant variable 
X_train_lm = sm.add_constant(X_train_new)

# %%
lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

# %%
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.842
# Model:                            OLS   Adj. R-squared:                  0.838
# Method:                 Least Squares   F-statistic:                     221.2
# Date:                Tue, 15 Mar 2022   Prob (F-statistic):          1.69e-190
# Time:                        20:49:15   Log-Likelihood:                 509.47
# No. Observations:                 510   AIC:                            -992.9
# Df Residuals:                     497   BIC:                            -937.9
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                            0.2841      0.034      8.242      0.000       0.216       0.352
# ...

# %% [markdown]
# ### Checking VIF for multicollinearity

# %%
# Calculate the VIFs for the new model
calculateVIF(X_train_new)
# Out:
#                         Features    VIF
# 0                          const  74.38
# 1                  season_Spring   5.02
# 10                          temp   3.61
# 3                  season_Winter   3.49
# 2                  season_Summer   2.61
# 11                           hum   1.90
# 7       weathersit_Mist & Cloudy   1.56
# 4                       mnth_Jul   1.48
# 5                       mnth_Sep   1.30
# 6   weathersit_Light Snow & Rain   1.24
# 12                     windspeed   1.19
# 8                             yr   1.03
# 9                        holiday   1.02

# %% [markdown]
# #### We generally want a VIF that is less than 5 .

# %%
X_train_new = X_train_new.drop(['const'], axis=1)

# %%
# Calculate the VIFs for the new model again
calculateVIF(X_train_new)
# Out:
#                         Features    VIF
# 10                           hum  28.06
# 9                           temp  16.02
# 11                     windspeed   4.65
# 0                  season_Spring   4.01
# 2                  season_Winter   3.35
# 1                  season_Summer   2.78
# 6       weathersit_Mist & Cloudy   2.28
# 7                             yr   2.08
# 3                       mnth_Jul   1.58
# 4                       mnth_Sep   1.38
# 5   weathersit_Light Snow & Rain   1.24
# 8                        holiday   1.04

# %% [markdown]
# ### StatsModel - Linear Model #3 (Dropping Humidity based on non-zero P value)

# %%
### dropping hum from the model
X_train_new = X_train_new.drop(['hum'], axis=1)

# %%
# Adding a constant variable 
X_train_lm = sm.add_constant(X_train_new)

# Create a first fitted model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
# Check the summary
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.836
# Model:                            OLS   Adj. R-squared:                  0.832
# Method:                 Least Squares   F-statistic:                     230.4
# Date:                Tue, 15 Mar 2022   Prob (F-statistic):          2.40e-187
# Time:                        20:49:19   Log-Likelihood:                 499.17
# No. Observations:                 510   AIC:                            -974.3
# Df Residuals:                     498   BIC:                            -923.5
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                            0.1996      0.030      6.758      0.000       0.142       0.258
# ...

# %%
# Calculate the VIFs for the new model again
calculateVIF(X_train_new)
# Out:
#                         Features   VIF
# 9                           temp  5.09
# 10                     windspeed  4.60
# 1                  season_Summer  2.21
# 0                  season_Spring  2.08
# 7                             yr  2.07
# 2                  season_Winter  1.79
# 3                       mnth_Jul  1.58
# 6       weathersit_Mist & Cloudy  1.55
# 4                       mnth_Sep  1.34
# 5   weathersit_Light Snow & Rain  1.08
# 8                        holiday  1.04

# %% [markdown]
#     ### Dropping Temp leads to huge drops in R-squared:  hence did not drop ###

# %% [markdown]
# ### StatsModel - Linear Model #4 (Dropping mnth_Jul based on non-zero P value)

# %%
### dropping hum from the model
X_train_new = X_train_new.drop(['windspeed'], axis=1)

# %%
# Adding a constant variable 
X_train_lm = sm.add_constant(X_train_new)

# Create a first fitted model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
# Check the summary
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.821
# Method:                 Least Squares   F-statistic:                     234.1
# Date:                Tue, 15 Mar 2022   Prob (F-statistic):          2.80e-181
# Time:                        20:49:20   Log-Likelihood:                 481.98
# No. Observations:                 510   AIC:                            -942.0
# Df Residuals:                     499   BIC:                            -895.4
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                            0.1503      0.029      5.134      0.000       0.093       0.208
# ...

# %%
# Calculate the VIFs for the new model again
calculateVIF(X_train_new)
# Out:
#                        Features   VIF
# 9                          temp  4.22
# 7                            yr  2.06
# 1                 season_Summer  1.93
# 2                 season_Winter  1.58
# 3                      mnth_Jul  1.58
# 6      weathersit_Mist & Cloudy  1.55
# 0                 season_Spring  1.40
# 4                      mnth_Sep  1.34
# 5  weathersit_Light Snow & Rain  1.07
# 8                       holiday  1.04

# %% [markdown]
# ### StatsModel - Linear Model #5 (Dropping windspeed based on P value)

# %%
### dropping hum from the model
X_train_new = X_train_new.drop(['season_Summer'], axis=1)
# Adding a constant variable 
X_train_lm = sm.add_constant(X_train_new)
# Create a first fitted model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
# Check the summary
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.823
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     257.5
# Date:                Tue, 15 Mar 2022   Prob (F-statistic):          2.16e-181
# Time:                        20:49:22   Log-Likelihood:                 479.38
# No. Observations:                 510   AIC:                            -938.8
# Df Residuals:                     500   BIC:                            -896.4
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                            0.1938      0.022      8.750      0.000       0.150       0.237
# ...

# %%
# Calculate the VIFs for the new model again
calculateVIF(X_train_new)
# Out:
#                        Features   VIF
# 8                          temp  2.99
# 6                            yr  2.05
# 5      weathersit_Mist & Cloudy  1.51
# 1                 season_Winter  1.33
# 2                      mnth_Jul  1.33
# 0                 season_Spring  1.25
# 3                      mnth_Sep  1.19
# 4  weathersit_Light Snow & Rain  1.06
# 7                       holiday  1.04

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <span style='font-family:Georgia'>
#         <b>Insight:</b>
#         <ul>
#         <li>a) Coefficient P value is zero</li>
#         <li>b) VIF is less than 5</li>
#         <li>c) R-squared and Adj. R-squared is greated than 80 </li>
#         <li>d) Difference between R-squared and Adj. R-squared is less  </li>
#         <li>e) F-statistics value is high </li>
#         <ul>
#     </span>
# </div>

# %%
# Validating Linear Relationship
sm.graphics.plot_ccpr(lm, 'temp')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qm/mkx_h9896xn7qg3fr_yk5s_80000gq/T/ipykernel_5483/4003950792.py in <module>
#       1 # Validating Homoscedasticity
# ----> 2 y_train_pred = lm.predict(X_train_new)
#       3 sns.scatterplot(y_train,(y_train - y_train_pred))
#       4 plt.plot(y_train,(y_train - y_train), '-r')
#       5 plt.xlabel('Count')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py in predict(self, exog, transform, *args, **kwargs)
#    1097             exog = np.atleast_2d(exog)  # needed in count model shape[1]
#    1098
# -> 1099         predict_results = self.model.predict(self.params, exog, *args,
#    1100                                              **kwargs)
#    1101
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/regression/linear_model.py in predict(self, params, exog)
# ...

# %% [markdown]
# # Step 6: Residual Analysis of the train data

# %%
# Validating Homoscedasticity
y_train_cnt = lm.predict(X_train_lm)
sns.scatterplot(y_train,(y_train - y_train_cnt))
plt.plot(y_train,(y_train - y_train), '-r')
plt.xlabel('Count')
plt.ylabel('Residual')
plt.show()

# %%
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y_train - y_train_cnt), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading 
plt.xlabel('Errors', fontsize = 18)                         # X-label
# Out:
# Text(0.5, 0, 'Errors')

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <span style='font-family:Georgia'>
#         <b>Insight:</b>
#         <ul>
#         <li>Errors are normally distributed <Answer>Linear Regression is a machine learning algorithm based on supervised learning.It performs a regression task.Regression models a target prediction value based on independent variables.It is mostly used for finding out the relationship between target variables and forecasting.</li>
#         <ul>
#     </span>
# </div>

# %% [markdown]
# # Step 7:  Predictions Using the Final Model
#
# Now that we have fitted the model and checked the normality of error terms, it's time to go ahead and make predictions using the final, i.e. third model.

# %% [markdown]
# ### Applying Scaling on the test sets

# %%
num_vars = ['cnt','hum','windspeed','temp','atemp']


test[num_vars] = scaler.transform(test[num_vars])

# %%
test.describe()
# Out:
#        season_Spring  season_Summer  season_Winter    mnth_Aug    mnth_Dec  \
# count     219.000000     219.000000     219.000000  219.000000  219.000000
# mean        0.255708       0.264840       0.232877    0.059361    0.086758
# std         0.437258       0.442259       0.423633    0.236840    0.282125
# min         0.000000       0.000000       0.000000    0.000000    0.000000
# 25%         0.000000       0.000000       0.000000    0.000000    0.000000
# 50%         0.000000       0.000000       0.000000    0.000000    0.000000
# 75%         1.000000       1.000000       0.000000    0.000000    0.000000
# max         1.000000       1.000000       1.000000    1.000000    1.000000
#
#          mnth_Feb    mnth_Jan    mnth_Jul    mnth_Jun    mnth_Mar    mnth_May  \
# count  219.000000  219.000000  219.000000  219.000000  219.000000  219.000000
# mean     0.100457    0.077626    0.105023    0.095890    0.054795    0.086758
# ...

# %% [markdown]
# ### Dividing into X_test and y_test

# %%
y_test = test.pop('cnt')
X_test = test

# %%
# Adding constant variable to test dataframe
X_test = sm.add_constant(X_test)

# %%
# predicting using values used by the final model
test_col = X_train_lm.columns
X_test=X_test[test_col[1:]]
# Adding constant variable to test dataframe
X_test = sm.add_constant(X_test)

X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219 entries, 184 to 72
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   const                         219 non-null    float64
#  1   season_Spring                 219 non-null    uint8
#  2   season_Winter                 219 non-null    uint8
#  3   mnth_Jul                      219 non-null    uint8
#  4   mnth_Sep                      219 non-null    uint8
#  5   weathersit_Light Snow & Rain  219 non-null    uint8
#  6   weathersit_Mist & Cloudy      219 non-null    uint8
#  7   yr                            219 non-null    int64
#  8   holiday                       219 non-null    int64
#  9   temp                          219 non-null    float64
# dtypes: float64(2), int64(2), uint8(6)
# memory usage: 9.8 KB

# %%
# Making predictions using the fourth model

y_pred = lm.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8092200832884748

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 0.009061246323057638

# %% [markdown]
# ## Step 9: Model Evaluation
#
# Let's now plot the graph for actual versus predicted values.

# %%
# Plotting y_test and y_pred to understand the spread

fig = plt.figure()
plt.scatter(y_test, y_pred)
fig.suptitle('y_test vs y_pred', fontsize = 20)              # Plot heading 
plt.xlabel('y_test', fontsize = 18)                          # X-label
plt.ylabel('y_pred', fontsize = 16)
# Out:
# Text(0, 0.5, 'y_pred')

# %% [markdown]
# # Feature Coefficients Values For Dependent Value (Cnt)

# %%
param = pd.DataFrame(lm.params)
param.insert(0,'Variables',param.index)
param.rename(columns = {0:'Coefficient value'},inplace = True)
param['index'] = list(range(0,10))
param.set_index('index',inplace = True)
param.sort_values(by = 'Coefficient value',ascending = False,inplace = True)
param
# Out:
#                           Variables  Coefficient value
# index
# 9                              temp           0.471172
# 7                                yr           0.233037
# 0                             const           0.193838
# 4                          mnth_Sep           0.065793
# 2                     season_Winter           0.055785
# 3                          mnth_Jul          -0.068771
# 6          weathersit_Mist & Cloudy          -0.079572
# 8                           holiday          -0.101113
# 1                     season_Spring          -0.110708
# 5      weathersit_Light Snow & Rain          -0.300245
